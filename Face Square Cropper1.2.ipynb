# %%
import os
import cv2
from PIL import Image

face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')#学習データ

#img_dir_path = input('画像フォルダのパスを入力してください：')#

img_dir_path = '/Users/user/Desktop/drive-download'
pictures = os.listdir(img_dir_path)#フォルダリストの中身をリスト化

if '.DS_Store' in pictures:
    pictures.remove('.DS_Store')

if 'thumbs.db' in pictures:
    pictures.remove('thumbs.db')
    
print(pictures)


#os.listdir(os.path.join(img_dir_path,pictures[i]))#
#img = cv2.imread(pictures[0])
os.mkdir(os.path.join(img_dir_path,'output'))

i = 0

while i < len(pictures):

    img = cv2.imread(os.path.join(img_dir_path,pictures[i]))
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, scaleFactor = 1.2, minSize = (300,300), maxSize = (1600,1600))


#    for (x, y, w, h) in faces:
#        cv2.rectangle(img, (x, y), (x+w, y+h), (0, 0, 255))
#        resized_img = cv2.resize(img,(450, 300))
#        cv2.imshow("test.jpg", resized_img)
#        cv2.waitKey(0)
#        cv2.destroyAllWindows 
    print(pictures[i])
    print(faces)

#顔認証に失敗し場合
    if len(faces) == 0:
        img = Image.open(os.path.join(img_dir_path,pictures[i]))
        im_crop = img.crop((100, 200, 300, 400))
        im_crop.save(os.path.join(img_dir_path,'output',pictures[i])+"【fail】.jpg", quality=100) #dpiも設定してください dpi=(300, 300))

    
#顔認証に成功した場合
    elif len(faces) > 0:
        face_max = faces[faces[:, 2].argmax()]

        print(face_max)

        img = Image.open(os.path.join(img_dir_path,pictures[i]))
        width, height = img.size

        print(face_max[0])

#クロップ位置の定義（顔を中心に正方形に切り取る）
        X1 = face_max[0]+0.5*face_max[2]-0.5*height
        Y1 = (face_max[1]+0.5*face_max[3]-0.5*width)*0.5#
        X2 = X1 + height
        Y2 = Y1 + width


#横写真だった場合の条件
        if X1 < 0:
            X1 = 0
            X2 = X1 + height
        
        if X2 > width:
            X2 = width
            X1 = X2 - height

        if Y1 < 0:
            Y1 = 0
            Y2 = Y1 + width

        if Y2 > height:
            Y2 = height
            Y1 = Y2 - width

        if width > height:#横写真の場合、以下のようにクロップ
            im_crop = img.crop((X1, 0, X2, height))
            im_crop.save(os.path.join(img_dir_path,'output',pictures[i]), quality=100) #dpiも設定してください dpi=(300, 300))
            
        elif width < height:#縦写真だった場合、
            im_crop = img.crop((0, Y1, width, Y2))
            im_crop.save(os.path.join(img_dir_path,'output',pictures[i]), quality=100) #dpiも設定してください dpi=(300, 300))

    i = i + 1 

print('END')

root.quit()
exit()
# Out:
# ['2311068.jpg', '2311054.jpg', '2311055.jpg', '2311069.jpg', '2311057.jpg', '2311056.jpg', '2311052.jpg', '2311053.jpg', '2311051.jpg', '2311061.jpg', '2311060.jpg', '2311062.jpg', '2311063.jpg', '2311067.jpg', '2311072.jpg', '2311066.jpg', '2311070.jpg', '2311064.jpg', '2311058.jpg', '2311059.jpg', '2311065.jpg', '2311071.jpg']
# 2311068.jpg
# [[ 806 1121  767  767]]
# [ 806 1121  767  767]
# 806
# 2311054.jpg
# [[1182  913  818  818]]
# [1182  913  818  818]
# 1182
# 2311055.jpg
# [[1878  593  971  971]]
# [1878  593  971  971]
# 1878
# 2311069.jpg
# [[1605  768  955  955]]
# [1605  768  955  955]
# 1605
# 2311057.jpg
# [[851 467 962 962]]
# [851 467 962 962]
# 851
# 2311056.jpg
# ()
# 2311052.jpg
# [[1126  645  725  725]]
# [1126  645  725  725]
# 1126
# 2311053.jpg
# [[1293  544  376  376]]
# [1293  544  376  376]
# 1293
# 2311051.jpg
# [[1062 1006  994  994]]
# [1062 1006  994  994]
# 1062
# 2311061.jpg
# [[929 786 855 855]]
# [929 786 855 855]
# 929
# 2311060.jpg
# [[1778  688  879  879]]
# [1778  688  879  879]
# 1778
# 2311062.jpg
# [[1177  399  834  834]]
# [1177  399  834  834]
# 1177
# 2311063.jpg
# [[ 689 1230  502  502]]
# [ 689 1230  502  502]
# 689
# 2311067.jpg
# [[799 888 879 879]]
# [799 888 879 879]
# 799
# 2311072.jpg
# [[ 493 2629  385  385]
#  [ 850 1242 1284 1284]]
# [ 850 1242 1284 1284]
# 850
# 2311066.jpg
# [[1260  938  897  897]]
# [1260  938  897  897]
# 1260
# 2311070.jpg
# [[1212  722  762  762]]
# [1212  722  762  762]
# 1212
# 2311064.jpg
# ()
# 2311058.jpg
# [[ 495  437 1402 1402]]
# [ 495  437 1402 1402]
# 495
# 2311059.jpg
# [[ 590 1100  506  506]]
# [ 590 1100  506  506]
# 590
# 2311065.jpg
# [[2106  683  782  782]]
# [2106  683  782  782]
# 2106
# 2311071.jpg
# [[ 174  676 1289 1289]]
# [ 174  676 1289 1289]
# 174
# END
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-c0ff1a1f5163> in <module>
#      95 print('END')
#      96
# ---> 97 root.quit()
#      98 exit()
#
# NameError: name 'root' is not defined
